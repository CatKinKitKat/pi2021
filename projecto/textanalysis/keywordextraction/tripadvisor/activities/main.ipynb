# %%
import os
import yake
import pandas

# %%
def main():
    current_dir = os.getcwd()
    path = current_dir + "/scrapes//tripadvisor/activities"
    keywords = get_keywords_chunks(path)
    print(keywords)
    i = 0
    for keyword in keywords:
        print(keyword)
        with open(
            current_dir
            + "/keywordextraction/tripadvisor/activities/place"
            + str(i)
            + ".csv",
            "w",
        ) as f:
            f.write("ExpressÃ£o, FrequÃªncia\n")
            for k in keyword:
                for word in k:
                    f.write(
                        str(word)
                        .replace("(", "")
                        .replace(")", "")
                        .replace("\u2010", "-")
                        + "\n"
                    )
        i += 1

# %%
def get_keywords_chunks(path, chunk_size=100000):
    keywords = []
    for file in os.listdir(path):
        if file.endswith(".csv") and not file.startswith("list"):
            df = import_csv_chunks(path + "/" + file, chunk_size)
            keywords.append(extract_keywords_chunks(df))
    return keywords

# %%
def get_keywords(path):
    keywords = []
    for file in os.listdir(path):
        if file.endswith(".csv") and not file.startswith("list"):
            df = import_csv(path + "/" + file)
            keywords.append(extract_keywords(df))
    return keywords

# %%
def import_csv(path):
    df = pandas.read_csv(path, encoding="utf-8")
    return df

# %%
def import_csv_chunks(path, chunk_size=100000):
    df = pandas.read_csv(
        path,
        encoding="utf-8",
        low_memory=False,
        memory_map=True,
        chunksize=chunk_size,
        on_bad_lines="skip",
    )
    return df

# %%
def spell_check(text):
    spell = SpellChecker(language="pt")
    ret = ""
    for word in str(text).split(" "):
        if word not in spell:
            ret += word + " "
        elif spell.correction(word) != word:
            ret += spell.correction(word) + " "
    return ret.strip()

# %%
def extract_keywords(df):
    keywords = []
    for i in range(0, len(df)):
        review = df["AvaliacÌ§oÌƒes"][i]
        keywords.append(yake.KeywordExtractor(lan="pt").extract_keywords(review))
    return keywords

# %%
def extract_keywords_chunks(chunks):
    keywords = []
    for df in chunks:
        for i in range(0, len(df)):
            review = df["Avaliacoes"][i]
            keywords.append(yake.KeywordExtractor(lan="pt").extract_keywords(review))
    return keywords

# %%
if __name__ == "__main__":
    main()
