# %% [markdown]
# # TripAdvisor
#
# ### Webscraping
#
# ##### Imports
#
# First we start with the imports. We need essentially three (or four) main libraries to work this out; these are:
#  + requests (to fetch the website)
#  + lxml (a faster html parser to speed bs4)
#  + bs4 (a.k.a beautiful soup, a web scraping library)
#  + pandas (a maths oriented data(set) manipulation library)
#
# Since requests uses urllib3 as a dependency, we can import it first to configure it to supress the annoying warning about the "insecure" connection (lack of SSL).

# %%
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
import requests
from bs4 import BeautifulSoup as soup
import pandas as pd
from random import randint
from time import sleep

# %% [markdown]
# ##### Request configuration
#
# We need to configure our request, specially in this case, since TripAdvisor wont send us a webpage if we at least not try to emulate a real browser.
# First we configure our headers, ripping the main headers from our browser, as seen in the Developer tools (F12) in Chromium (we used the new Microsoft Edge).
#
# Then we request the webpage (Hotels in Beja, Portugal) with our headers attached, a timeout to stop if it takes too long (something is wrong), and verification is disabled (SSL).
# If the status code is OK (200), doesn't print.
#
# After that we create a BeautifulSoup4 scrapable object with the html content of the page, using lxml.

# %%
headers = {
        'Access-Control-Allow-Origin': '*',
        'Access-Control-Allow-Methods': 'GET',
        'Access-Control-Allow-Headers': 'Content-Type',
        'accept': '*/*',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'en-GB,en;q=0.9,en-US;q=0.8',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36 Edg/96.0.1054.29'}
url = "https://www.tripadvisor.pt/Hotels-g189102-Beja_Beja_District_Alentejo-Hotels.html"
req = requests.get(url,headers=headers,timeout=5,verify=False)
req.status_code
bsobj = soup(req.content, 'lxml')

# %% [markdown]
# ##### Scraping
#
# Now we start scraping. First we start getting hotel names.

# %%
hotel = []
for name in bsobj.findAll('div',{'class':'listing_title'}):
  hotel.append(name.text.strip())
print(len(hotel))
# Out:
# 30

# %% [markdown]
# Then their ratings.

# %%
ratings = []
for rating in bsobj.findAll('a',{'class':'ui_bubble_rating'}):
  ratings.append(rating['alt'])
print(len(ratings))
# Out:
# 29

# %% [markdown]
# The number of reviews (they have a big issue).

# %%
reviews = []
for review in bsobj.findAll('a',{'class':'review_count'}):
  reviews.append(review.text.strip())
print(len(reviews))
# Out:
# 30

# %% [markdown]
# This number is referring to the TOTAL number of reviews. However, we can only scrape a single language, that's dependent of the domain/locale (.com .pt); there's no query parameter to change either the number here, or the sorting of reviews.
#
# Now we get the prices.

# %%
price = []
for p in bsobj.findAll('div',{'class':'price-wrap'}):
  price.append(p.text.replace('€','').strip()) 
print(len(price))
# Out:
# 25

# %% [markdown]
# Some of these will be empty, since the price is gotten via phone call.
#
# Now, we get to the weird part: Reviews. These reviews are handled by the hotel page in weird ways:
#  + only four shown per subpage
#  + each subpage is counted via a multiple of five
#  + any multiple of five non-existent will not give 404, but redirect to the first subpage
#  + language selection via scraping is non-existent, no query parameters, only radio buttons with random labels, defaults chosen via domain/locale (.com .pt)
#
# So the strategy found is:
#  + create a monstruos amount of subpage links (about 200)
#  + scrape all reviews, even repeated via the redirect to the first subpage
#  + later use sets, or dictionaries to remove duplicates
#
# That was done with this awful looking but functional code.

# %%
links = []
for review in bsobj.findAll('a',{'class':'review_count'}):
  try: 
    a = review['href']
    a = 'https://www.tripadvisor.pt'+ a
    c = a[:(a.find('Reviews')+7)] + '' + a[(a.find('Reviews')+7):]
    links.append(c)
    for i in range(5,1000,5):
        b = a[:(a.find('Reviews')+7)] + '-or' + str(i) + a[(a.find('Reviews')+7):]
        links.append(b)
  except:
    pass
print(links)
# Out:
# ['https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or5-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or10-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or15-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or20-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or25-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or30-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or35-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or40-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or45-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or50-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or55-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or60-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or65-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or70-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or75-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or80-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or85-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or90-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or95-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or100-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or105-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or110-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or115-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or120-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or125-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or130-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or135-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or140-Pousada_Convento_Beja-Beja_Beja_District_Alentejo.html#REVIEWS', 'https://www.tripadvisor.pt/Hotel_Review-g189102-d239324-Reviews-or145-Pousada_Co ...

# %% [markdown]
# Now, we get the smallest length number of the arrays regarting to the hotels, hoping we remove some of the (repeated) sponsorships.

# %%
# bad code
length = len(price)
if length > len(reviews):
    length = len(reviews)
if length > len(hotel):
    length = len(hotel)
if length > len(ratings):
    length = len(ratings)

# %% [markdown]
# And then create the ID table of the hotels with the most basic information in a pandas DataFrame, and export that one to a .csv file that we can use in Exel, PowerBI, ML libraries like Keras, Tensorflow, SciKitLearn can use.

# %%
d1 = {'Hotel':hotel[:length],'Estrelas':ratings[:length],'Avaliações':reviews[:length],'Preço':price[:length]}
df = pd.DataFrame.from_dict(d1)
print(df)
df.to_csv('listtable.csv')
# Out:
#                                   Hotel         Estrelas        Avaliações  \
# 0                 Pousada Convento Beja  4,5 de 5 bolhas    751 avaliações
# 1              Vila Galé Clube de Campo  4,5 de 5 bolhas    917 avaliações
# 2                     Herdade dos Grous  4,5 de 5 bolhas    229 avaliações
# 3                         Hotel Bejense    4 de 5 bolhas    192 avaliações
# 4                        Herdade do Vau  4,5 de 5 bolhas     76 avaliações
# 5                  Herdade Da Diabroria    4 de 5 bolhas     54 avaliações
# 6                          Hotel Melius    4 de 5 bolhas     90 avaliações
# 7                      BejaParque Hotel  3,5 de 5 bolhas    159 avaliações
# 8                    Hotel São Domingos    4 de 5 bolhas    135 avaliações
# 9                    Maria`s Guesthouse    5 de 5 bolhas      7 avaliações
# 10                  Hotel Santa Bárbara    4 de 5 bolhas     62 avaliações
# 11                          Beja Hostel  3,5 de 5 bolhas     35 avaliações
# 12           Império romano guest house  4,5 de 5 bolhas      5 avaliações
# 13                  Guest House Stories    5 de 5 bolhas       1 avaliação
# 14  Monte Das Beatas - Alojamento Local    5 de 5 bolhas       1 avaliação
# 15               Hospedaria Santa Maria    3 de 5 bolhas      6 avaliações
# 16                   Aljana Guest House  4,5 de 5 bolhas      0 avaliações
# 17        Sesmarias Turismo Rural & SPA    5 de 5 bolhas    113 avaliações
# 18                Monte da Floresta B&B  3,5 de 5 bolhas     19 avaliações
# 19                     Casa de Pedrogao    4 de 5 bolhas     28 avaliações
# 20                    Hotel Santa Clara    5 de 5 bolhas     32 avaliações
# 21        Herdade das Barradas da Serra    5 de 5 bolhas    229 avaliações
# 22                 Paradise In Portugal    5 de 5 bolhas    407 avaliações
# 23                     Villa Extramuros    5 de 5 bolhas    186 avaliações
# 24               Albergaria Do Calvario    5 de 5 bolhas  2 286 avaliações
#
#     Preço
# 0     100
# 1      99
# 2     130
# 3      63
# 4      85
# 5      76
# 6      75
# 7      80
# 8      55
# 9   85 81
# 10     59
# 11     50
# 12     67
# 13     50
# 14     50
# 15     36
# 16     99
# 17     90
# 18  80 76
# 19  54 51
# 20     58
# 21    125
# 22     79
# 23
# 24

# %% [markdown]
# Now the most horrible of codes presents you with the creations of various, separated .csv files with the scraped reviews, that we can use.
#
# It iterates all the links and since there's 200 links per hotel, every 200 we use some list comprehension magic with sets to remove duplicates and export the DataFrame to a useful .csv file.

# %%
count = 0
count2 = 0
allreviews = []
for link in links:
    try:
        html2 = requests.get(link,headers=headers)
        bsobj2 = soup(html2.content,'lxml')
        for r in bsobj2.findAll('q'):
            try:
                rev = r.span.text.strip()
                allreviews.append(rev + '\n')
            except:
                pass
    except:
        pass
    count += 1
    if count == 200:
        seen = set()
        allreviews = [item for item in allreviews if not(tuple(item) in seen or seen.add(tuple(item)))]
        dfr = pd.DataFrame.from_dict({'Avaliações':allreviews})
        print(dfr)
        dfr.to_csv('hotel' + str(count2) + '.csv')
        allreviews = []
        count = 0
        count2 += 1
# Out:
#                                             Avaliações
# 0    Excelente hotel .  Pessoal da recepção e servi...
# 1    Património histórico ao seu melhor nível de re...
# 2    Chegámos depois da meia-noite e fomos recebido...
# 3    Gostei muito do alojamento e da estadia. Desta...
# 4    Na reserva tinha a descrição de um tipo de qua...
# ..                                                 ...
# 324  Não é pode esperar de um hotel de luxo e não o...
# 325  A Pousada em beja, como muitos, tem uma antigo...
# 326  A primeira estadia em uma pousada e nós impres...
# 327  O hotel se hospedado por uma noite em este sle...
# 328  Duas das US hospedado aqui para uma noite em m...
#
# [329 rows x 1 columns]
#                                             Avaliações
# 0    Hotel localizado no "meio" do Alentejo, mais p...
# 1    Ideal para uns excelentes momentos, descontrai...
# 2    Excelente local! A comida é fantástica! Os vin...
# 3    Este hotel nunca falha , espaços para crianças...
# 4    Éramos um casal com filhos gémeos de 12 anos e...
# ..                                                 ...
# 801  Não há minibar nos quartos e ouvir tudo no qua...
# 802  O hotel se hospedaram no hotel por uma noite n...
# 803  Este hotel oferece várias childrens atividades...
# 804  Se desejar uma boa estadia, em uma tranqüila.....
# 805  O Clube de Campo é um nice farm tipo resort pa...
#
# [806 rows x 1 columns]
#                                            Avaliações
# 0   Pense num lugar onde tudo é lindo. Adicione a ...
# 1   Fomos a Herdade para um almoço de familia. Lug...
# 2   Jantar espetacular em convívio com colegas de ...
# 3   Desde nossa chegada,ficamos muito bem impressi...
# 4   Adorei a herdade. É enorme. Foi pena ser pouco...
# ..                                                ...
# 92  Que lugar maravilhoso! Super limpo e bem prese...
# 93  Ótimo resort com instalações agradáveis. Dormi...
# 94  No ano passado fomos para a herdade da porta a...
# 95  Tivemos grandes esperanças para a visita a est...
# 96  Fomos a esta adega por uma noite porque alguns...
#
# [97 rows x 1 columns]
#                                            Avaliações
# 0   Hotel muito bem decorado, com quartos temático...
# 1   Desde o primeiro contacto até ao check-out sem...
# 2   Pura e simplesmente uma vergonha e um atentado...
# 3   Hotel pitoresco, bem situado, com bom pequeno-...
# 4   Bom Hotel, bem localizado no centro da cidade ...
# ..                                                ...
# 74  Eu fiquei recentemente em este hotel encantado...
# 75  Hotel encantador e histórico. Passamos 2 dias ...
# 76  Este hotel é ideal no centro da cidade. |Os qu...
# 77  Nós chegaram em beja--impulsivamente--que muda...
# 78  O Residencial Bejense é um encantador hotel de...
#
# [79 rows x 1 columns]
#                                            Avaliações
# 0   Propriedade a apenas 20 min de Beja (cujo cami...
# 1   Localizada a cerca 2h de caminhose lisboa, Ape...
# 2   Paisagem bonita! Com muito potencial para turi...
# 3   Uma beleza arrasadora! simplicidade  modernida...
# 4   A funcionária que nos serviu o pequeno-almoço ...
# 5   Como é um local bem cotado, escolhemos para fe...
# 6   Fomos em família ficar neste hotel e foi muito...
# 7   O acesso é por terra batida durante vários kms...
# 8   Ao fim de alguns quilómetros em estrada de ter...
# 9   É um dos sítios que gostaria de voltar assim q...
# 10  A Herdade é fantástica para quem gosta de rela...
# 11  A Herdade do Vau é um excelente local para des...
# 12  Fizemos a reserva para ficarmos em um lugar tr...
# 13  Quanto um conjunto tão grande de "Excelentes" ...
# 14  Depois de muita pesquisa para um grupo de 8, e...
# 15  Local Paradisíaco, ideal para relaxar, sonhar ...
# 16  Situado num sitio maravilhoso! fomos recebidos...
# 17  Mesmo com um acesso complicado, vale a pena um...
# 18  Para quem quer descansar, gozar uma belíssima ...
# 19  Local de eleição  para curtas temporadas. No m...
# 20  Quem pensa  que é preciso sair de Portugal par...
# 21  O que Vos vou confessar peço que não digam a n...
# 22  Quem pretender conhecer a forma como se recebe...
# 23  Sitio ideal para descansar, escrever um livro,...
# 24  Fui com os meus filhos mais velhos  e com uns ...
# 25  Se procuram descanso num pequeno, subtil rusti...
# 26  Eu e minha família ficamos lá por uma noite e ...
# 27  Estou apaixonada pela Herdade do Vau! A partir...
# 28  Foi, de longe e grande o melhor para encontrar...
# 29  Depois de uma semana muito agitada do trabalho...
# 30  Vau Vinhas é um sonho para o vino novatos, bem...
# 31  Nós apreciamos a paisagem, o hotel rural, a tr...
#                                            Avaliações
# 0   Ficamos 3 noites em agosto21 numa mezzanine co...
# 1   O que se vê nas fotos não retrata a 100% a rea...
# 2   Foram muito prestáveis a dar informações e até...
# 3   Deve se ter atenção que está a poucos km do ce...
# 4   Espetacular, simpatia do staff, pequeno almoço...
# 5   Local muito giro! Ficamos numa suite espaçosa ...
# 6   A Herdade está bem cuidada, tem uns ótimos qua...
# 7   Fiquei apenas uma noite na herdade, mas supero...
# 8   Tipo rustico e tem todas as comodidades, os qu...
# 9   O espaço é muito bonito. O serviço é 5 estrela...
# 10  O quarto grande e wc limpos. O acolhimento foi...
# 11  Um bom lugar para se passar uns bons dias de f...
# 12  Quartos espacosos assim como wc. Eramos varios...
# 13  Foram 4 dias de estadia excelentes, boa compan...
# 14  Espaço fantástico! O quarto onde ficamos é eno...
# 15  Uma herdade muito agradável com vistas deslumb...
# 16  Ambiente agradável, piscina simpática e quarto...
# 17  Paz e ver o tempo passar é o que nos aguarda e...
# 18  Fiz a reserva de uma suite para 2 adultos e um...
# 19  Sitio ideal para relaxar em família, bastante ...
# 20  Óptimo para parar e relaxar um fim de semana, ...
# 21  Equipa fantástica! Lugar calmo e aprazível, qu...
# 22  Sítio muito agradável, com pessoas muito simpá...
# 23  Herdade muito bonita e bem conservada... Excel...
# 24  Local aprazível na planície alentejana junto a...
# 25  A herdade é grande e bonita, sem dúvida. A pai...
# 26  Fomos realmente muito bem atendidos. Serviço m...
# 27  Fácil acesso. Algumas actividades: campo de té...
# 28  Muito agradável, sossego, paisagens maravilhos...
# 29  Espaço bonito, sossegado, talvez sossegado dem...
# 30  Acolhimento muito bom, pessoas atenciosas é se...
# 31  Para quem procura um momento de pausa do bulíc...
# 32  Acolhimento fantástico! O Monte está muito bem...
# 33  Local aprazível, com boas acomodações, e as pe...
# 34  Funcionários simpáticos, quarto pré aquecido à...
# 35  O local é agradável e espaçoso. Fomos muito be...
# 36  Escolhemos este alojamento de turismo rural co...
# 37  Um local fantástico com uma envolvente muito n...
# 38  Muito bom! Um ambiente familiar muito recomend...
# 39  O Monte da Diabrória é muito bonito e situa-se...
# 40  "Autoridade Superior" estava tendo um aniversá...
# 41  Eu queria visitar a área e de Beja este lugar ...
# 42  Ficamos aqui por 4 noites. O nosso quarto era ...
# 43  Serviço: a equipe foi estelar. D Adriana realm...
#                                            Avaliações
# 0   O hotel tem um preço bastante agradável e as i...
# 1   Bom hotel, bem localizado, renovado e bem deco...
# 2   Quando se está em Beja uma ótima opção para sa...
# 3   Os quartos esteticamente são engraçados, mas s...
# 4   Funcionários sempre disponíveis. Muito boas co...
# ..                                                ...
# 59  Quarto foi bom. Hotel foi impecáveis com boa d...
# 60  Eu fiquei uma semana neste hotel durante uma v...
# 61  Muito bom 3 * hotel. Gratuito e rápido acesso ...
# 62  Eu estava com amigos no hotel. Boas lembranças...
# 63  Olá! Um dos meu amigo português sugeriu-me est...
#
# [64 rows x 1 columns]
#                                            Avaliações
# 0   Ficámos  no hotel duas noites, na primeira noi...
# 1   No geral há uma imensa falta de atenção ao det...
# 2   Recomendo este hotel, acusticamente irrepreens...
# 3   Num fim de semana, com covid à  solta, optamos...
# 4   Excelentes férias em família. Hotel acolhedor,...
# ..                                                ...
# 91  O hotel está cansado. As toalhas são finas e d...
# 92  Ficar aqui pela segunda vez, para nós é conven...
# 93  Caiu sobre este hotel no caminho de volta para...
# 94  Convenientemente Situado na extremidade do reb...
# 95  Moderno hotel localizado a uma curta distância...
#
# [96 rows x 1 columns]
#                                            Avaliações
# 0   Estive hospedado neste hotel de 1 a 3 de julho...
# 1   O quarto tinha uma grande lomba no chão de mad...
# 2   Hotel muito bem localizado, charmoso, atendime...
# 3   Estive entre os dias 5 a 7 de Setembro hospeda...
# 4   O hotel é acolhedor com bonitos jardins, estan...
# ..                                                ...
# 82  Muito bom, áreas, perfeitamente localizado jun...
# 83  Hotel São Domingos está maravilhosamente resta...
# 84  É a minha terceira estadia neste hotel e eu ma...
# 85  I teve chance de ficar no hotel são domingos, ...
# 86  de tudo, por lagos, campo, vilas pitorescas, u...
#
# [87 rows x 1 columns]
#                                           Avaliações
# 0  Mesmo muito bom! Super limpo e acolhedor. Desd...
# 1  Uma casa típica,  acolhedora e muito bem decor...
# 2  O espaço remodelado no centro histórico, com t...
#                                            Avaliações
# 0   O Hotel é muito acolhedor, o pequeno-almoço te...
# 1   Hotel muito familiar, bastante tranquilo, a eq...
# 2   Excelente hotel para a relação preço qualidade...
# 3   Pessoas muito cordiais na recepção,localizado ...
# 4   Não é um quarto gigante, mas é muito confortáv...
# 5   Um excelente hotel localizado numa rua com pou...
# 6   Hotel muito simples, nada a apontar à limpeza ...
# 7   Check-in muito atabalhuado  mesmo com reserva ...
# 8   Ficámos alojados por uma noite neste "hotel". ...
# 9   Esta Pensão fica bem situada. Mesmo no centro ...
# 10  O hotel é pequeno mas confortável. Bem no cent...
# 11  Se for no Verão, contar com imenso calor. Pequ...
# 12  Um serviço bom. Boa receção a clientes. Limpez...
# 13  Muito desactualizada. Limpeza mediana. Pequeno...
# 14  Está bem localizado no centro da cidade. O ser...
# 15  O hotel para passar uns dias 2 a 3 está bem o ...
# 16  Sem grandes mordomias, tem tudo o que é necess...
# 17  Situado no centro da cidade, todos os quartos ...
# 18  Hotel Santa Barbara, e ótimo para aquilo que o...
# 19  Um Hotel pequeno e familiar. Excelente localiz...
# 20  Pros:Um hotel com boas condições, bom pequeno ...
# 21  O Hotel fica situado numa das artérias princip...
# 22  A localização é o ponto forte deste hotel. Os ...
# 23  Duas estrelas com elevador, localização privil...
# 24  Fiquei hospedado neste hotel 3 noites, tem ópt...
# 25  Óptima localização.Mesmo no centro da cidade.A...
# 26  O hotel fica na zona central da cidade, junto ...
# 27  Estivemos recentemente no Hotel Santa Bárbara,...
# 28  Optima localização no centro da cidade,solução...
# 29  Este é um hotel muito centralmente localizado ...
# 30  O hotel está bem localizado no centro, em uma ...
# 31  Ótima localização na zona histórica de Beja. O...
# 32  Este é um hotel muito acolhedor com uma equipa...
# 33  É limpo, Nice, central residencial. A equipe é...
#                                            Avaliações
# 0   1. Chamada grosseira recebida no dia de check-...
# 1   Viemos passar 3 dias a Beja e escolhemos o Hos...
# 2   Quarto pouco acolhedor e um bocadinho frio  Ca...
# 3   nao recomendo ao meu maior inimigo, pequeno al...
# 4   Sem duvidas uma boa opção para quem quer conhe...
# 5   Bom serviço e ambiente acolhedor. Pequenos alm...
# 6   O hostel apresenta uma decoração acolhedora e ...
# 7   O hostel está numa boa localização da cidade d...
# 8   Não gostámos, o Hostel estava em obras! O quar...
# 9   Hostel com uma decoração muito simpática, econ...
# 10  Está localizado perto do centro histórico e da...
# 11  Hostel bem decorado econômico em termos de pre...
# 12  Bons quartos com WC privado, decoração moderna...
# 13  Aparentemente interessante... e com varios pon...
# 14  Apesar de simples,  a decoração é moderna com ...
# 15  O Hostel foi renovado recentemente. As instala...
# 16  Gostei Muito Desde o Atendimento muito bom, fi...
# 17  O Hostel de Beja é muito limpo. A decoração é ...
# 18  Basicamente, enganaram-me! Disseram-me que o p...
# 19  Segunda vez estadia aqui, com meu marido e nov...
#                                           Avaliações
# 0  Guest house confortevole con un bizarro arreda...
# 1  Belle expérience par les lieux tout à fait par...
# 2  Super accueil, hôtes très sympathiques chambre...
# 3  Excelente alojamento, muito bem localizado no ...
# 4  Très bien placé, à quelques pas de la place de...
#                                           Avaliações
# 0  Localização central com estacionamento perto m...
#                                           Avaliações
# 0  Helena & Jorge were very welcoming. The farm i...
#                                           Avaliações
# 0  Para quem procura um alojamento moderno, esta ...
# 1  Péssima experiência e atendimento! Preço da re...
# 2  Excelente localização. Boa limpeza e funcionár...
# 3  Hospedaria limpa e com funcionários simpáticos...
# 4  A Hospedaria é muito antiga e está pouco cuida...
#                                            Avaliações
# 0   Não tem recepção disponivel 24 h fiquei a dorm...
# 1   No meio do Alentejo este local é ideal para de...
# 2   Estivemos alojados por 5 dias nas sesmarias e ...
# 3   Rodeado das mais belas planícies alentejanas, ...
# 4   Pontos positivos: Lugar genuinamente alentejan...
# ..                                                ...
# 90  Espaço excelente e ideal para quem procura um ...
# 91  Tudo óptimo!! Fomos no pacote Fim-de-semana Ro...
# 92  Estabelecimento novo, ainda com pormenores por...
# 93  Nós ficamos com a família 3 noites lá. O iníci...
# 94  O quarto foi ok, no entanto não foi chaleira, ...
#
# [95 rows x 1 columns]
#                                            Avaliações
# 0   Local calmo, acolhedor e com a simpatia de pro...
# 1   A tranquilidade existe aqui. Um silêncio tranq...
# 2   Tudo o que passo a mencionar é pouco ou será p...
# 3   O espaço é extremamente limpo, o Sr. José Luis...
# 4   Tudo muito bom, começando logo pela localizaçã...
# 5   Tudo ótimo, Simpatia do proprietário, limpeza,...
# 6   A simpatia da funcionária, fizeram-nos sentir ...
# 7   Não é fácil encontrar palavras suficientes e s...
# 8   Excepcional, em termos de qualidade do acolhim...
# 9   Queriamos um lugar descontraído e sossegado pa...
# 10  Uma quinta recuperada para B&B. O dono está pr...
# 11  Fantástico! Confirmo tudo o que de bom tem sid...
# 12  Simpatia e disponibilidade do anfitrião, sempr...
# 13  Mesmo ao lado da N2 com excelentes condições d...
# 14  Raquel e José super prestáveis, disponíveis e ...
# 15  Foi uma surpresa agradável, este Monte em Ferr...
# 16  Pertinho da vila ds Ferreira do Alentejo, exis...
# 17  Lugar fantástico e hospitalidade!  Uma recepçã...
#                                            Avaliações
# 0   Casa bem organizada de forma a acomodar de for...
# 1   Local muito tranquilo e óptimo para descansar,...
# 2   A experiência neste alojamento não foi a melho...
# 3   Este alojamento faz parte do leque de opções d...
# 4   Simpatia no acolhimento, apartamento muito agr...
# 5   Passámos uma noite no local. Quarto razoável f...
# 6   Várias casas e quartos no local. Uma piscina f...
# 7   Ligamos com a proprietária e explicamos que pr...
# 8   Local agradável para umas boas férias em famíl...
# 9   Local muito agradável. Fomos muito bem atendid...
# 10  Adorei tudo! Desde o espaço, decoração, cuidad...
# 11  Terra de gente muito simpática e muito atencio...
# 12  No centro da aldeia de Pedrógão surge este tur...
# 13  Estupendo! Tranquilo, acolhedor, muito limpo, ...
# 14  Bom atendimento; casa bem equipada e confortáv...
# 15  Quarto asseado e confortável. Espaço exterior ...
# 16  Decoração, pormenores, espaços comuns, tudo mu...
# 17  Os apartamentos são muito confortáveis e limpo...
# 18  Enganaram-se na nossa reserva, o que nos fez a...
# 19  Alojamento em duplex T1 com grande qualidade, ...
# 20  O pequeno-almoço é farto e variado. A limpeza ...
# 21  Excelente para descanso, boa piscina, quartos ...
# 22  Queríamos conhecer o Alqueva o que acabou por ...
# 23  Localizado no coração do Alentejo, na recatada...
# 24  Simpatia da colaboradora que me atendeu é de d...
# 25  casa bem arranjada e agradavel,mas uma das coi...
# 26  Excelente local para descanso em familia, num ...
# 27  Aconselho a estadia. No Alentejo perto de Mour...
#                                            Avaliações
# 0   Excelente valor de qualidade. Lo aqui alguns c...
# 1   Dou 6* em 5* Serviço soberbo Funcionários exce...
# 2   Comfirmo este hôtel nao merece as 2*.... Quand...
# 3   Um hotel simples, com um bom serviço, acolhedo...
# 4   Muito bom hotel na área onde está.  Atendiment...
# 5   Dos melhores hotéis onde já estive. Empregados...
# 6   Hotel simpático, espaços agradáveis e bem cuid...
# 7   Limpeza dos quartos e demais instalações, simp...
# 8   Hotel simples, limpo.  Bem situado, fácil esta...
# 9   Hotel simpático. Pequeno mas com muitos quarto...
# 10  Quando pensamos em hotéis 2* talvez não pensem...
# 11  Mesmo ao pé do jardim, é simples mas aparente ...
# 12  Passamos dois dias excelentes  no  hotel santa...
# 13  Instalações razoáveis um pouco antiquadas em m...
# 14  Residencial calma e muito simples, atendimento...
# 15  Hotel agradável,  com as comodidades essenciai...
# 16  Atendimento muito simpático. Local bem situado...
# 17  Atendimento 5*  Muito bom pequeno almoço Limpe...
# 18  Boa localização, boa relação qualidade/preço, ...
# 19  Somos clientes habituais desta residencial que...
# 20  Pequeno hotel, com muito bom aspeto e confortá...
# 21  Optimo para quem tem que levar animais.  Levei...
# 22  Hotelzinho simpático e muito limpo. Bom acolhi...
# 23  Se hospedado por 2 noites. Os quartos são muit...
#                                            Avaliações
# 0   Estadia muito agradável. A herdade é bonita e ...
# 1   Qualidade dos quartos, excepcional simpatia e ...
# 2   A Herdade das Barradas da Serra é óptima para ...
# 3   O local, as pessoas, a comida... tudo fantásti...
# 4   A Herdade Barradas da Serra é um lugar encanta...
# ..                                                ...
# 71  O lugar perfeito para desfrutar de um pouco de...
# 72  Meu marido e eu ficamos na Herdade das Barrada...
# 73  Nós ficamos 2 noites aqui, e foi realmente imp...
# 74  Um lugar esteja no maravilhoso para alcançar a...
# 75  Se hospedar no herdade das Barradas da Serra f...
#
# [76 rows x 1 columns]
#                                             Avaliações
# 0    A experiencia foi simplesmente incrível. O esp...
# 1    Fomos sem expetativa muito alta e acabámos des...
# 2    A Quinta é incrível.  A vista da barragem é ma...
# 3    Este sítio é muito bonito a comida é fantástic...
# 4    Fica no meio de nada e próxima das aguas da ba...
# ..                                                 ...
# 117  Quinta do barranco de estrada    o Quinta é ma...
# 118  Website - (---)  Este lugar é mágica. VISITEI ...
# 119  Meu Noivo e I passado três noites aqui e veio ...
# 120  Paraíso em Portugal é seu website endereço e é...
# 121  Este lugar é imperdível para quem quer ver o i...
#
# [122 rows x 1 columns]
#                                            Avaliações
# 0   Conhecia este lugar de referências em revistas...
# 1   Mais uma vez o Alentejo “demonstrou” o quanto ...
# 2   A Villa Extramuros é um daqueles locais que qu...
# 3   Além das instalações fantásticas, muito espaço...
# 4   Villa design com boa localização  e com um sta...
# 5   Projeto e decoração com preocupação em cada de...
# 6   Adoramos a Arquitectura e o bom gosto da decor...
# 7   Há alguns anos que tinha tido conhecimento des...
# 8   Linda propriedade, integrada a natureza e deco...
# 9   Imperdível para quem adora arquitetura e decor...
# 10  A casa tem um design fantástico e com muito bo...
# 11  Simplesmente apaixonados pelo local! Os propri...
# 12  Ao chegar à Villa Extramuros, somos agradavelm...
# 13  Excelente escolha para famílias pequenas ou ca...
# 14  Localização privilegiada, arquitectura e decor...
# 15  A pouco mais de 1 hora de Lisboa, encontra-se ...
# 16  Um ambiente muito acolhedor numa casa soberba,...
# 17  Este lugar é incrível! Desde pequenos-almoços ...
# 18  Escondida no campo, esta deslumbrante vila é o...
# 19  Perfeição! Todos os pormenores são perfeitos -...
# 20  A Villa Extremura fez parte da nossa lista de ...
# 21  Nós apreciamos 5 noites aqui, 4 em um dos caba...
# 22  Meu amigo e I se hospedaram no Villa Extramuro...
# 23  Tivemos uma experiência maravilhosa nesta casa...
# 24  Nós se hospedaram no Villa Extramuros no iníci...
# 25  NÓS NÃO PODERAMOS AMAR ESTE HOTEL MAIS! ! ! ! ...
# 26  Despretenciosamente elegante com peças de desi...
# 27  Eu tenho vindo a visitar desde que li sobre es...
# 28  Eu quase não quero mesmo escrever um comentári...
# 29  Muito diferente de qualquer outra acomodação n...
# 30  Optámos por ficar no Villa Extramuros no final...
# 31  Meu marido e I se hospedaram no Villa Extramur...
# 32  É assim que tudo deve ser feito. Vivendo a vid...
# 33  Nós ficamos na bela casa concebida e organizad...
# 34  Meu marido e eu passamos duas semanas viajando...
# 35  Se você gosta de seu B&Bs projetado com interi...
# 36  Extremamente elegante, pequeno hotel boutique ...
# 37  Este lugar parece casa, os proprietários estão...
# 38  Há lugares onde você sempre quer voltar ... Vi...
# 39  François e Jean-Christophe criaram uma Villa e...
# 40  Os nossos quatro noite se hospedar no Villa Ex...
# 41  Nós já passamos uma semana no Villa Extramuros...
# 42  Excelente, eu vou começar com as calorosas boa...
# 43  A combinação de ambiente, natureza fantástica,...
# 44  Recentemente, passei duas noites no Villa Extr...
# 45  Passamos 2 dias com as bonitas villa Extramuro...
# 46  4 Noites em este lugar maravilhoso e simplesme...
# 47  Arraiolos é muito bonito, bem como ao redor do...
# 48  Apenas passamos 4 noites no Villa Extramuros e...
# 49  Simplesmente o melhor lugar em Portugal! Conce...
#                                             Avaliações
# 0    O hotel é bem localizado, limpo, os funcionári...
# 1    Excelente localização, tudo funciona, tudo mui...
# 2    Uma atenção superior, localização excepcional....
# 3    Albergaria localizada dentro das muralhas e pe...
# 4    Uma verdadeira pérola escondida. Hotel lindíss...
# ..                                                 ...
# 696  O Hotel adorei esse hotel! Excelente localizaç...
# 697  Recentemente (2007) comprado por um American e...
# 698  maravilhoso estabelecimento em uma bela cidade...
# 699  Este hotel foi fácil de encontrar e estacionam...
# 700  Meu marido e I hospedado aqui para 2 noites no...
#
# [701 rows x 1 columns]
#                                             Avaliações
# 0    Excelente vale bem a pena  Recomendo vivamente...
# 1    Área da piscina excelente, regras Covid muito ...
# 2    Junto a Monsaraz, na estrada para a praia fluv...
# 3    A estadia no Monte Alerta por todas as razões ...
# 4    Que sítio fabuloso! Espaços muito agradáveis e...
# ..                                                 ...
# 165  Excelente casa com uma só alma. Para qualquer ...
# 166  Home care e espaços verdes  Espaço bem decorad...
# 167  Monte Alerta é um "monte alentejano tradiciona...
# 168  Monsaraz é um mouro inesquecível vila fortific...
# 169  Monsaraz é um belo lugar para se visitar no Al...
#
# [170 rows x 1 columns]
#                                             Avaliações
# 0    Dificilmente se encontrarão locais sem mácula ...
# 1    Alojamento simples de grande qualidade. Silenc...
# 2    Desde já a anfitriã, Rita é espectacular de ta...
# 3    Outeiro do Barro, uma agradável pousada nos ar...
# 4    Instalações acolhedoras, simples mas confortáv...
# ..                                                 ...
# 109  Acabados de sair do Outeiro do Barro, depois d...
# 110  Só ficámos uma noite no Outeiro do Barro, mas ...
# 111  Fomos de fim de semana ate ao alentejo e ficam...
# 112  Adorei este sitio, simpatia da Rita e da Sra s...
# 113  Gostei muito de ter estado uma noite neste tur...
#
# [114 rows x 1 columns]
#                                            Avaliações
# 0   Um local extraordinário para passar alguns dia...
# 1   Monte Saraz continua a ser o nosso "oásis de s...
# 2   Por vezes, procuramos por aquele local onde po...
# 3   Fui sem saber para onde, uma surpresa da minha...
# 4   Tivemos uma estadia muito agradável. Adorámos ...
# 5   Monte Saraz" - turismo rural de excelente qual...
# 6   Bem localizada perto do Castelo de Monsaraz e ...
# 7   Monte magnifico situado num ponto absolutament...
# 8   Foi uma estadia maravilhosa, certamente a repe...
# 9   Se um dia quiser descansar com toda a paz e bo...
# 10  Regressamos a este paraiso no campo apos 20 an...
# 11  Se um dia quiser descansar com toda a paz e bo...
# 12  Monte Saraz e um sitio ótimo para relaxar dura...
# 13  Estadia deliciosa, intercâmbio com a Natureza,...
# 14  Lugar magnifico, um autêntico paraíso no lindo...
# 15  Grata pela simpatia de todos as pessoas. Excel...
# 16  Onze dias muito bem passados sempre com a aten...
# 17  Este lugar é um verdadeiro oásis no Alentejo. ...
# 18  Um lugar perfeito para relaxar e descansar! Su...
# 19  Excelente local para passar um fim-de-semana. ...
# 20  O Local é muito bonito, tanto seus jardins, co...
# 21  Imaginar una música a subir em espiral, elevan...
# 22  Maravilhoso! Turismo rural cinco estrelas! Qua...
# 23  Um dos melhores turismos rurais da região, se ...
# 24  Um local calmo, com uma vista espetacular para...
# 25  Estamos muito satisfeitos com a estadia. Fomos...
# 26  Foi com enorme surpresa que percebemos que o M...
# 27  Já aqui viemos umas 5 vezes, nos últimos anos....
# 28  Descobrir este hotel rural foi um acaso... mas...
# 29  Foi um fim-de-semana inesquecível! A casa, os ...
# 30  Excelente, relaxante, com pequeno almoço com p...
# 31  Adorámos os jardins refrescantes e verdes comu...
# 32  Já tínhamos estado no Monte Saraz há uns 6 ano...
# 33  O Monte Saraz é, para nós, um refúgio de tranq...
# 34  Passei aqui uma um fim de semana com o meu mar...
# 35  Monte Saraz ......Na minha memória tinha ficad...
# 36  O Castelo de Monsaraz, descreve a história de ...
# 37  Numa zona calma no meio de Alentejo, Portugal,...
# 38  Local tranquilo, bom para descanso. Grande sim...
# 39  Meu marido, tive a oportunidade de permanecer ...
# 40  Minha família e I se hospedaram no Monte Saraz...
# 41  Inicialmente pensei que 13 noites seria demasi...
# 42  Muito bom retiro campestre perto de atrações d...
# 43  Passamos duas noites em março de se hospedar n...
# 44  No entanto, ficamos a apenas as pessoas se hos...
# 45  Monte Saraz é, sem dúvida o melhor lugar que s...
# 46  A quinta remodelada e pouco villas estão bonit...
# 47  Monte Sï¿½ um velho mundo villa intocada aninh...
# 48  O encantador hotel boutique de Marc é um pouco...
# 49  Monte Sï¿½ é uma verdadeira jóia abaixo da bel...
# 50  Um segredo bem tratados, um tesouro escondido,...
# 51  Monte Saraz é o que em minha mente uma villa r...
# 52  Se você como pássaros, plantas, caminhada e um...
# 53  A aproximadamente meia hora de carro a partir ...
#                                             Avaliações
# 0    Excelente para uns dias de descanso em família...
# 1    Staff muito simpático e sempre preocupado com ...
# 2    O Monte do Giestal é o sítio perfeito para ir ...
# 3    Vivamente recomendado. Todos muito simpaticos ...
# 4    Espaço super agradável, ideal para uns dias de...
# ..                                                 ...
# 114  Ficámos hospedados neste hotel apenas uma noit...
# 115  Estive hospedado nesta pequena vila e adorei. ...
# 116  Estivemos hospedados neste espaço durante 3 no...
# 117  Se quiser relaxar com a sua família é o local ...
# 118  Nós (minha esposa, dois filhos (19 e 17) e eu ...
#
# [119 rows x 1 columns]
#                                            Avaliações
# 0   O Imani fica perto de Évora e ainda mais perto...
# 1   Local magnífico para descansar em paz, num amb...
# 2   Visita com amigos em tempo de pandemia e ainda...
# 3   Ideal para um momento a dois ou em família, em...
# 4   Superou as minhas expectativas! foi um fim de ...
# ..                                                ...
# 76  É um belo e tranquilo lugar em um cenário natu...
# 77  Tivemos um maravilhoso par de noites de estadi...
# 78  Belos jardins, com uma arquitectura interessan...
# 79  Excelente design interior, moderno e rústico. ...
# 80  Imani Country House é uma jóia, um canto inesp...
#
# [81 rows x 1 columns]
